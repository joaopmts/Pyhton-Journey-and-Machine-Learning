# %% [markdown]
# ## PYTHON JOURNEY MACHINE & DEEP LEARNING
# ### Trabalho prático usando Python
#
# ### Principal Component Analysis  (PCA)
# ### Dimensionality Reduction

# %% [markdown]
# ### Exemplo de aplicação da técnica de PCA
#
# #### Objetivo: Criar uma segmentação de países utilizando os recordes femininos da modalidade esportiva de corridas. Para o desenvolvimento do modelo será utilizada uma base disponível no site da universidade de Wisconsin através do endereço: http://www.stat.wisc.edu/~rich/JWMULT06dat/T1-9.dat.
#
# #### Nesta base temos os recordes femininos internacionais, referência 2005, das seguintes modalidades: 100 metros em segundos, 200 metros em segundos, 400 metros em segundos, 800 metros em minutos, 1.500 metros em minutos, 3.000 metros em minutos e maratona em minutos.
#
# #### Dicionário de variáveis
#
# ![Dic_corrida.png](attachment:Dic_corrida.png)

# %%
# Importar as bibliotecas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
import os

local = f"{os.path.abspath('')}"

# %matplotlib inline

# %%
# Importar os dados
dados = pd.read_csv(f"{local}\Base_Paises.csv", sep=";")

# %%
dados.head()
# Out:
#   PAIS  p100ms  p200ms  p400ms  p800mm  p1500mm  p3000mm  pmaratm
# 0  ARG   11.57   22.94   52.50    2.05     4.25     9.19   150.32
# 1  AUS   11.12   22.23   48.63    1.98     4.02     8.63   143.51
# 2  AUT   11.15   22.70   50.62    1.94     4.05     8.78   154.35
# 3  BEL   11.14   22.48   51.45    1.97     4.08     8.82   143.05
# 4  BER   11.46   23.05   53.30    2.07     4.29     9.81   174.18

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PAIS     54 non-null     object
#  1   p100ms   54 non-null     float64
#  2   p200ms   54 non-null     float64
#  3   p400ms   54 non-null     float64
#  4   p800mm   54 non-null     float64
#  5   p1500mm  54 non-null     float64
#  6   p3000mm  54 non-null     float64
#  7   pmaratm  54 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 3.5+ KB

# %%
dados.describe().T
# Out:
#          count        mean        std     min       25%      50%       75%  \
# p100ms    54.0   11.357778   0.394101   10.49   11.1225   11.325   11.5675
# p200ms    54.0   23.118519   0.929025   21.34   22.5700   22.980   23.6100
# p400ms    54.0   51.989074   2.597202   47.60   49.9675   51.645   53.1175
# p800mm    54.0    2.022407   0.086873    1.89    1.9700    2.005    2.0700
# p1500mm   54.0    4.189444   0.272365    3.84    4.0025    4.100    4.3375
# p3000mm   54.0    9.080741   0.815327    8.10    8.5425    8.845    9.3250
# pmaratm   54.0  153.619259  16.439895  135.25  143.4800  148.430  157.6650
#
#             max
# p100ms    12.52
# p200ms    25.91
# p400ms    61.65
# p800mm     2.29
# p1500mm    5.42
# p3000mm   13.12
# pmaratm  221.14

# %%
print(dados)
# Out:
#      PAIS  p100ms  p200ms  p400ms  p800mm  p1500mm  p3000mm  pmaratm
# 0     ARG   11.57   22.94   52.50    2.05     4.25     9.19   150.32
# 1     AUS   11.12   22.23   48.63    1.98     4.02     8.63   143.51
# 2     AUT   11.15   22.70   50.62    1.94     4.05     8.78   154.35
# 3     BEL   11.14   22.48   51.45    1.97     4.08     8.82   143.05
# 4     BER   11.46   23.05   53.30    2.07     4.29     9.81   174.18
# 5     BRA   11.17   22.60   50.62    1.97     4.17     9.04   147.41
# 6     CAN   10.98   22.62   49.91    1.97     4.00     8.54   148.36
# 7     CHI   11.65   23.84   53.68    2.00     4.22     9.26   152.23
# 52    TUR   11.25   22.71   53.15    2.01     3.92     8.53   151.43
# 53    USA   10.49   21.34   48.83    1.94     3.95     8.43   141.16

# %%
dados.isna().sum()
# Out:
# PAIS       0
# p100ms     0
# p200ms     0
# p400ms     0
# p800mm     0
# p1500mm    0
# p3000mm    0
# pmaratm    0
# dtype: int64

# %%
# draw boxplots to visualize outliers

plt.figure(figsize=(24,20))


plt.subplot(4, 2, 1)
fig = dados.boxplot(column='p100ms')
fig.set_title('')
fig.set_ylabel('p100ms')


plt.subplot(4, 2, 2)
fig = dados.boxplot(column='p200ms')
fig.set_title('')
fig.set_ylabel('p200ms')


plt.subplot(4, 2, 3)
fig = dados.boxplot(column='p400ms')
fig.set_title('')
fig.set_ylabel('p400ms')

plt.subplot(4, 2, 4)
fig = dados.boxplot(column='p800mm')
fig.set_title('')
fig.set_ylabel('p800mm')

plt.subplot(4, 2, 5)
fig = dados.boxplot(column='p1500mm')
fig.set_title('')
fig.set_ylabel('p1500mm')

plt.subplot(4, 2, 6)
fig = dados.boxplot(column='p3000mm')
fig.set_title('')
fig.set_ylabel('p3000mm')


plt.subplot(4, 2, 7)
fig = dados.boxplot(column='pmaratm')
fig.set_title('')
fig.set_ylabel('pmaratm')
# Out:
# Text(0, 0.5, 'pmaratm')

# %%
# Excluindo outliers e selecionando somente as variáveis segmentadoras

#aux = dados[dados['pmaratm'] < 180] 
# dados_semout = aux.drop(['PAIS'], axis=1)

dados_semout = dados.drop(['PAIS'], axis=1)

dados_semout.describe()
# Out:
#           p100ms     p200ms     p400ms     p800mm    p1500mm    p3000mm  \
# count  54.000000  54.000000  54.000000  54.000000  54.000000  54.000000
# mean   11.357778  23.118519  51.989074   2.022407   4.189444   9.080741
# std     0.394101   0.929025   2.597202   0.086873   0.272365   0.815327
# min    10.490000  21.340000  47.600000   1.890000   3.840000   8.100000
# 25%    11.122500  22.570000  49.967500   1.970000   4.002500   8.542500
# 50%    11.325000  22.980000  51.645000   2.005000   4.100000   8.845000
# 75%    11.567500  23.610000  53.117500   2.070000   4.337500   9.325000
# max    12.520000  25.910000  61.650000   2.290000   5.420000  13.120000
#
#           pmaratm
# count   54.000000
# mean   153.619259
# std     16.439895
# min    135.250000
# 25%    143.480000
# 50%    148.430000
# 75%    157.665000
# max    221.140000

# %%
# Análise exploratória dos dados
#sb.pairplot()
sb.pairplot(dados_semout)

# %%
# Matriz de Correlação de Pearson
dados_semout.corr(method='pearson')
# Out:
#            p100ms    p200ms    p400ms    p800mm   p1500mm   p3000mm   pmaratm
# p100ms   1.000000  0.941089  0.870780  0.809176  0.781551  0.727878  0.668960
# p200ms   0.941089  1.000000  0.908810  0.819826  0.801328  0.731855  0.679954
# p400ms   0.870780  0.908810  1.000000  0.805790  0.719800  0.673799  0.676938
# p800mm   0.809176  0.819826  0.805790  1.000000  0.905051  0.866573  0.853990
# p1500mm  0.781551  0.801328  0.719800  0.905051  1.000000  0.973380  0.790557
# p3000mm  0.727878  0.731855  0.673799  0.866573  0.973380  1.000000  0.798730
# pmaratm  0.668960  0.679954  0.676938  0.853990  0.790557  0.798730  1.000000

# %%
# Matriz de correlação
sb.heatmap(dados_semout.corr(), cmap='coolwarm', annot = True);

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit
#   -7.39144854e-01 -6.81827299e-01 -5.79559218e-01]
#  [-1.47983082e-01 -2.59151321e-01 -2.68453029e-02 -4.92737532e-01
#   -8.50325417e-01 -7.18967858e-01 -6.34204153e-01]
#  [-1.47983082e-01 -8.34998432e-01 -8.19681379e-01 -1.18988583e+00
#   -1.07268654e+00 -8.92290467e-01 -6.82709207e-01]
#  [-1.50544328e+00 -1.35652034e+00 -1.11893813e+00 -1.30607721e+00
#   -1.18386711e+00 -8.67530094e-01 -7.55773783e-01]
#  [ 2.61816222e+00  2.53316392e+00  1.68319329e+00  3.10919534e+00
#    4.56046198e+00  5.00067823e+00  2.33074404e+00]
#  [ 1.97785081e+00  1.54444529e+00  1.20127333e+00  1.13394183e+00
#    1.22504509e+00  1.06377897e+00  4.85505349e-02]
#  [-7.62682037e-01 -8.02403312e-01 -9.01296858e-01 -7.25120298e-01
#   -6.65024479e-01 -7.43728231e-01 -4.36500008e-01]
#  [-5.06557473e-01 -3.24341560e-01 -1.16233684e-01 -3.76546149e-01
#   -3.68542977e-01 -3.35182082e-01 -1.98272653e-01]
#  [-4.55332560e-02 -2.59151321e-01 -2.60032384e-01 -4.92737532e-01
#   -8.13265229e-01 -5.95165995e-01 -4.97898811e-01]
#  [-3.52882734e-01 -6.06832595e-01  2.91843708e-01  6.69176299e-01
#    7.06202465e-01  6.79993197e-01  3.62912406e-01]
#  [-7.11457124e-02  1.97180353e-01  2.37433389e-01  4.36793533e-01
#    7.06202465e-01  1.22472140e+00  5.38512982e-01]
#  [-2.76045364e-01 -4.43856998e-01  4.51188214e-01 -1.44163383e-01
#   -9.98566168e-01 -6.81827299e-01 -1.34417898e-01]
#  [-2.22259206e+00 -1.93236746e+00 -1.22775877e+00 -9.57503065e-01
#   -8.87385605e-01 -8.05629162e-01 -7.64983603e-01]]

# %%
from sklearn.decomposition import PCA

# %%
# Pedindo a quantidade de componentes possíveis p variáveis pode ser gerado até p componnetes
pca = PCA(n_components=7)

# %%
pca.fit(scaled_df)
# Out:
# PCA(n_components=7)

# %%
print('Auto-valores:')
x = pca.explained_variance_
print(x.sum())

# a soma dos auto-valores é igual a quantidade de variáveis
# Out:
# Auto-valores:
# 7.132075471698115

# %%
# Quanto da variância é explicada por cada componente.
print('Variância Explicada:')
print(pca.explained_variance_ratio_)
print()
# Out:
# Variância Explicada:
# [0.82966064 0.08981335 0.03990494 0.01779353 0.01299596 0.0077884
#  0.00204318]

# %%
print('Auto-vetores:')
print(pca.components_)
print()
# Out:
# Auto-vetores:
# [[ 0.37776568  0.3832103   0.36803611  0.39478099  0.38926095  0.37609448
#    0.35520305]
#  [ 0.40717562  0.41362907  0.45935314 -0.16124587 -0.30908771 -0.42318992
#   -0.3892153 ]
#  [-0.14058027 -0.10078325  0.23702554  0.14754239 -0.42198552 -0.40606271
#    0.74106097]
#  [-0.58706293 -0.19407501  0.64543118  0.29520804  0.06669044  0.08015699
#   -0.3210764 ]
#  [-0.16706891  0.09350016  0.32727328 -0.81905467  0.026131    0.35169796
#    0.24700821]
#  [-0.5396973   0.74493139 -0.24009405  0.01650651  0.18898771 -0.24049968
#    0.04826992]
#  [ 0.08893934 -0.26565662  0.12660435 -0.19521315  0.73076817 -0.57150644
#    0.08208401]]

# %%
from pandas import DataFrame

loadings = DataFrame(pca.components_.T)
loadings.index = ['PC %s' % pc for pc in loadings.index + 1]
loadings.columns = ['TS %s' % pc for pc in loadings.columns + 1]
loadings
# Out:
#           TS 1      TS 2      TS 3      TS 4      TS 5      TS 6      TS 7
# PC 1  0.377766  0.407176 -0.140580 -0.587063 -0.167069 -0.539697  0.088939
# PC 2  0.383210  0.413629 -0.100783 -0.194075  0.093500  0.744931 -0.265657
# PC 3  0.368036  0.459353  0.237026  0.645431  0.327273 -0.240094  0.126604
# PC 4  0.394781 -0.161246  0.147542  0.295208 -0.819055  0.016507 -0.195213
# PC 5  0.389261 -0.309088 -0.421986  0.066690  0.026131  0.188988  0.730768
# PC 6  0.376094 -0.423190 -0.406063  0.080157  0.351698 -0.240500 -0.571506
# PC 7  0.355203 -0.389215  0.741061 -0.321076  0.247008  0.048270  0.082084

# %%
# Gráfico Scree Plot

perc = pca.explained_variance_ratio_ * 100

perc = DataFrame(perc, columns=['Percentage explained ratio'], index=['PC %s' % pc for pc in np.arange(len(perc)) + 1])
ax = perc.plot(kind='bar')

# %%
# base padronizada

scaled_df.shape
# Out:
# (54, 7)

# %%
scaled_df.round(2)
# Out:
# array([[ 0.54, -0.19,  0.2 ,  0.32,  0.22,  0.14, -0.2 ],
#        [-0.61, -0.97, -1.31, -0.49, -0.63, -0.56, -0.62],
#        [-0.53, -0.45, -0.53, -0.96, -0.52, -0.37,  0.04],
#        [-0.56, -0.69, -0.21, -0.61, -0.41, -0.32, -0.65],
#        [ 0.26, -0.07,  0.51,  0.55,  0.37,  0.9 ,  1.26],
#        [-0.48, -0.56, -0.53, -0.61, -0.07, -0.05, -0.38],
#        [-0.97, -0.54, -0.81, -0.61, -0.7 , -0.67, -0.32],
#        [ 0.75,  0.78,  0.66, -0.26,  0.11,  0.22, -0.09],
#        [-1.45, -1.2 , -0.85, -1.07, -1.3 , -1.21, -0.87],
#        [-0.12, -0.22, -0.91,  0.2 ,  0.56,  0.36,  0.1 ],
#        [ 2.98,  3.03,  3.75,  2.99,  2.34,  2.5 ,  3.6 ],
#        [ 0.93,  0.87,  0.23,  0.9 ,  1.23,  0.94,  0.66],
#        [-0.69, -1.25, -1.55, -1.54, -0.59, -0.26, -0.52],
#        [ 0.16,  0.26,  0.36, -0.03, -0.26, -0.46, -0.26],
#        [ 0.7 ,  0.86,  0.4 ,  0.79,  1.3 ,  1.  ,  0.79],
#        [-0.58, -0.79, -0.72, -0.14, -0.33, -0.48, -0.35],
#        [-1.61, -1.23, -1.45, -0.96, -0.59, -0.55, -0.33],
#        [-1.4 , -1.53, -1.71, -1.19, -0.85, -0.71, -0.75],
#        [-0.66, -1.11, -0.99, -0.96, -0.81, -0.88, -1.13],
#        [-1.35, -0.49, -0.56, -0.26, -0.37, -0.15, -0.01],
#        [ 1.44,  1.5 ,  1.42,  1.48,  1.08,  0.78,  1.09],
#        [ 0.13, -0.06, -0.19, -0.38, -0.63, -0.66, -0.31],
#        [ 0.52,  0.81,  1.2 ,  0.9 ,  0.63,  0.52,  0.04],
#        [ 0.06, -0.32, -0.36, -0.26, -0.33,  0.04,  0.28],
#        [ 0.18, -0.11, -0.36, -0.14, -0.78, -0.89, -0.7 ],
#        [ 0.24,  0.03,  0.03,  0.55,  0.19,  0.31,  0.17],
#        [-0.56, -0.56, -0.26, -0.73, -0.78, -0.61, -0.62],
#        [ 0.01,  0.23, -0.02, -0.14, -0.11, -0.42, -0.87],
#        [ 0.67,  0.27, -0.17, -0.61, -0.85, -0.86, -0.93],
#        [ 0.34,  0.74,  0.65,  0.79,  0.19, -0.09, -0.46],
#        [ 1.13,  2.15,  1.65, -0.61,  0.22, -0.15, -0.51],
#        [ 1.03,  0.91,  1.59,  0.55,  0.6 ,  0.16, -0.27],
#        [ 0.36,  0.27,  0.22,  1.13,  0.74,  0.28,  0.96],
#        [ 0.93,  0.77,  1.02,  0.44,  0.52,  0.2 ,  0.83],
#        [-0.69,  0.01, -1.2 , -0.03,  0.  , -0.24, -0.59],
#        [ 0.77,  0.62,  0.38,  0.09,  0.04, -0.  ,  0.29],
#        [-0.71, -0.34, -0.25, -1.07, -0.48, -0.63, -0.63],
#        [-0.1 ,  0.01, -0.15, -0.61, -0.33, -0.4 , -0.44],
#        [ 0.13,  0.21,  0.18,  0.09, -0.67, -0.68, -0.77],
#        [ 1.54,  1.7 ,  1.24,  2.53,  1.6 ,  1.4 ,  4.15],
#        [-0.2 ,  0.25,  1.07,  1.13,  0.82,  0.9 ,  0.73],
#        [-1.1 , -1.07, -1.05, -0.84, -0.74, -0.68, -0.58],
#        [-0.15, -0.26, -0.03, -0.49, -0.85, -0.72, -0.63],
#        [-0.15, -0.83, -0.82, -1.19, -1.07, -0.89, -0.68],
#        [-1.51, -1.36, -1.12, -1.31, -1.18, -0.87, -0.76],
#        [ 2.62,  2.53,  1.68,  3.11,  4.56,  5.  ,  2.33],
#        [ 1.98,  1.54,  1.2 ,  1.13,  1.23,  1.06,  0.05],
#        [-0.76, -0.8 , -0.9 , -0.73, -0.67, -0.74, -0.44],
#        [-0.51, -0.32, -0.12, -0.38, -0.37, -0.34, -0.2 ],
#        [-0.05, -0.26, -0.26, -0.49, -0.81, -0.6 , -0.5 ],
#        [-0.35, -0.61,  0.29,  0.67,  0.71,  0.68,  0.36],
#        [-0.07,  0.2 ,  0.24,  0.44,  0.71,  1.22,  0.54],
#        [-0.28, -0.44,  0.45, -0.14, -1.  , -0.68, -0.13],
#        [-2.22, -1.93, -1.23, -0.96, -0.89, -0.81, -0.76]])

# %%
# Pontuando a base com o PCA

x_pca = pca.transform(scaled_df)

# %%
# base pontuada com PCA

x_pca.shape
# Out:
# (54, 7)

# %%
# base componentes principais
x_pca.round(2)
# Out:
# array([[ 0.4 ,  0.13, -0.26,  0.03, -0.3 , -0.48,  0.13],
#        [-1.95, -0.5 , -0.17, -0.33, -0.38, -0.1 , -0.06],
#        [-1.27, -0.19,  0.26, -0.3 ,  0.52,  0.05,  0.03],
#        [-1.3 ,  0.  , -0.17,  0.3 ,  0.17, -0.21,  0.06],
#        [ 1.41, -0.77,  0.58,  0.04,  0.3 , -0.4 , -0.14],
#        [-1.02, -0.38, -0.32, -0.02,  0.24, -0.06,  0.1 ],
#        [-1.75, -0.27,  0.24, -0.02,  0.01,  0.32, -0.08],
#        [ 0.82,  0.88, -0.27, -0.19,  0.44, -0.02, -0.06],
#        [-3.02, -0.05,  0.36,  0.32,  0.06,  0.08, -0.03],
#        [ 0.  , -0.95, -0.46, -0.38, -0.3 ,  0.15,  0.1 ],
#        [ 7.98,  0.53,  1.28,  0.17,  0.39, -0.18, -0.07],
#        [ 2.19, -0.34, -0.44, -0.36, -0.21,  0.15,  0.12],
#        [-2.43, -0.77, -0.4 , -0.71,  0.51, -0.29,  0.05],
#        [-0.08,  0.72,  0.13,  0.11, -0.09,  0.07,  0.05],
#        [ 2.21, -0.44, -0.34, -0.17,  0.03,  0.22,  0.17],
#        [-1.28, -0.43,  0.05,  0.04, -0.36, -0.07,  0.1 ],
#        [-2.54, -1.13,  0.09, -0.02,  0.17,  0.29,  0.04],
#        [-3.08, -0.94, -0.14, -0.21,  0.05, -0.02,  0.02],
#        [-2.47,  0.03, -0.31, -0.08, -0.14, -0.24,  0.11],
#        [-1.21, -0.78,  0.28,  0.42,  0.15,  0.46, -0.2 ],
#        [ 3.33,  0.53,  0.24,  0.  , -0.28,  0.09,  0.05],
#        [-0.8 ,  0.6 ,  0.19, -0.29, -0.11, -0.06, -0.03],
#        [ 1.76,  0.52, -0.18,  0.65, -0.15,  0.04, -0.02],
#        [-0.36, -0.26,  0.23, -0.39,  0.13, -0.25, -0.14],
#        [-1.05,  0.78,  0.05, -0.26, -0.55, -0.06, -0.09],
#        [ 0.58, -0.22, -0.03,  0.02, -0.33, -0.13, -0.12],
#        [-1.56,  0.28,  0.08,  0.15,  0.16, -0.1 , -0.06],
#        [-0.49,  0.66, -0.48,  0.13, -0.24,  0.21,  0.05],
#        [-0.93,  1.39, -0.23, -0.56, -0.2 , -0.13, -0.12],
#        [ 0.84,  0.78, -0.24,  0.46, -0.56,  0.26, -0.09],
#        [ 1.47,  2.4 , -0.49, -0.03,  0.88,  0.64,  0.06],
#        [ 1.74,  1.29, -0.3 ,  0.54, -0.02, -0.19,  0.26],
#        [ 1.51, -0.54,  0.42, -0.03, -0.53,  0.09,  0.23],
#        [ 1.77,  0.53,  0.41, -0.12,  0.18, -0.07,  0.26],
#        [-1.01, -0.5 , -0.53, -0.22, -0.48,  0.7 , -0.12],
#        [ 0.82,  0.6 ,  0.13, -0.4 ,  0.05, -0.02, -0.01],
#        [-1.56,  0.29, -0.09,  0.12,  0.5 ,  0.21,  0.16],
#        [-0.76,  0.44, -0.14, -0.14,  0.21,  0.1 ,  0.04],
#        [-0.56,  1.  ,  0.  ,  0.17, -0.46,  0.04, -0.2 ],
#        [ 5.31, -1.21,  2.11, -0.8 , -0.21,  0.34,  0.06],
#        [ 1.78, -0.59,  0.25,  0.99, -0.  ,  0.03, -0.03],
#        [-2.3 , -0.5 ,  0.05,  0.01,  0.02,  0.03,  0.02],
#        [-1.19,  0.71,  0.15,  0.06, -0.04, -0.13, -0.11],
#        [-2.14,  0.38,  0.04, -0.56,  0.14, -0.39,  0.01],
#        [-3.07, -0.45,  0.18,  0.13,  0.31, -0.  , -0.09],
#        [ 8.29, -2.05, -1.99, -0.07,  0.26, -0.11, -0.17],
#        [ 3.12,  0.97, -0.89, -0.2 , -0.3 , -0.21, -0.01],
#        [-1.91, -0.25,  0.13, -0.16, -0.04,  0.05,  0.08],
#        [-0.85, -0.  ,  0.17,  0.19,  0.15,  0.05,  0.01],
#        [-1.12,  0.53,  0.11, -0.18, -0.05, -0.15, -0.17],
#        [ 0.67, -1.02, -0.03,  0.7 , -0.1 , -0.33,  0.19],
#        [ 1.24, -0.85, -0.29,  0.26,  0.33,  0.  , -0.25],
#        [-0.86,  0.58,  0.77,  0.42, -0.03, -0.32, -0.17],
#        [-3.33, -1.2 ,  0.21,  0.73,  0.08,  0.03,  0.1 ]])

# %% [markdown]
# # Extraindo e plotando dois componentes

# %%
from sklearn.decomposition import PCA

line = dict(linewidth=1, linestyle='--', color='k')
marker = dict(linestyle='none', marker='o', markersize=7, color='red', alpha=0.5)


pca = PCA(n_components=2, copy=True)
X_2 = pca.fit_transform(scaled_df)

fig, ax = plt.subplots()
ax.plot(X_2[:, 0], X_2[:, 1], **marker) 
ax.set_xlim([-2, 2])
ax.set_ylim([-2, 2])
ax.axhline(**line)
ax.axvline(**line)
_ = ax.set_title("PCA")

#para ver se é aleatorio fazer correlação de pierce

# %% [markdown]
# # Selecionando somente 1 componente

# %%
pca_1 = PCA(n_components=1)

# %%
pca_1.fit(scaled_df)
# Out:
# PCA(n_components=1)

# %%
x_pca_1 = pca_1.transform(scaled_df)

# %%
# Check the dimensions of data after PCA
x_pca_1.shape
# Out:
# (54, 1)

# %%
x_pca_1.round(2)
# Out:
# array([[ 0.4 ],
#        [-1.95],
#        [-1.27],
#        [-1.3 ],
#        [ 1.41],
#        [-1.02],
#        [-1.75],
#        [ 0.82],
#        [-3.02],
#        [ 0.  ],
#        [ 7.98],
#        [ 2.19],
#        [-2.43],
#        [-0.08],
#        [ 2.21],
#        [-1.28],
#        [-2.54],
#        [-3.08],
#        [-2.47],
#        [-1.21],
#        [ 3.33],
#        [-0.8 ],
#        [ 1.76],
#        [-0.36],
#        [-1.05],
#        [ 0.58],
#        [-1.56],
#        [-0.49],
#        [-0.93],
#        [ 0.84],
#        [ 1.47],
#        [ 1.74],
#        [ 1.51],
#        [ 1.77],
#        [-1.01],
#        [ 0.82],
#        [-1.56],
#        [-0.76],
#        [-0.56],
#        [ 5.31],
#        [ 1.78],
#        [-2.3 ],
#        [-1.19],
#        [-2.14],
#        [-3.07],
#        [ 8.29],
#        [ 3.12],
#        [-1.91],
#        [-0.85],
#        [-1.12],
#        [ 0.67],
#        [ 1.24],
#        [-0.86],
#        [-3.33]])

# %%
# Check the values of eigen vectors
# prodeced by principal components

pca_1.components_
# Out:
# array([[0.37776568, 0.3832103 , 0.36803611, 0.39478099, 0.38926095,
#         0.37609448, 0.35520305]])

# %%
PCA_1 = x_pca_1[:,0]

# %%
PCA_1
# Out:
# array([ 3.96932712e-01, -1.94978078e+00, -1.27437528e+00, -1.30385947e+00,
#         1.40921784e+00, -1.01623241e+00, -1.75062584e+00,  8.19461265e-01,
#        -3.01753763e+00,  1.94577236e-03,  7.98046573e+00,  2.18715760e+00,
#        -2.42862265e+00, -8.32701560e-02,  2.21299627e+00, -1.27862579e+00,
#        -2.54199265e+00, -3.07613241e+00, -2.46564299e+00, -1.20904762e+00,
#         3.32505522e+00, -7.95652644e-01,  1.75829868e+00, -3.57583068e-01,
#        -1.04563426e+00,  5.79553038e-01, -1.56198323e+00, -4.86180315e-01,
#        -9.26352832e-01,  8.38595689e-01,  1.46901288e+00,  1.73763210e+00,
#         1.50924998e+00,  1.76615748e+00, -1.00511641e+00,  8.23643423e-01,
#        -1.55926573e+00, -7.62327056e-01, -5.58196096e-01,  5.30681655e+00,
#         1.78009305e+00, -2.29511616e+00, -1.18628541e+00, -2.14294047e+00,
#        -3.07152112e+00,  8.29053808e+00,  3.12297104e+00, -1.90720408e+00,
#        -8.47029079e-01, -1.12400129e+00,  6.65281943e-01,  1.23529643e+00,
#        -8.58110393e-01, -3.33012743e+00])

# %%
PCA_1.round(2)
# Out:
# array([ 0.4 , -1.95, -1.27, -1.3 ,  1.41, -1.02, -1.75,  0.82, -3.02,
#         0.  ,  7.98,  2.19, -2.43, -0.08,  2.21, -1.28, -2.54, -3.08,
#        -2.47, -1.21,  3.33, -0.8 ,  1.76, -0.36, -1.05,  0.58, -1.56,
#        -0.49, -0.93,  0.84,  1.47,  1.74,  1.51,  1.77, -1.01,  0.82,
#        -1.56, -0.76, -0.56,  5.31,  1.78, -2.3 , -1.19, -2.14, -3.07,
#         8.29,  3.12, -1.91, -0.85, -1.12,  0.67,  1.24, -0.86, -3.33])

# %%
Basefim = DataFrame(PCA_1)

# %%
Basefim.columns = ['PCA_1']

# %%
Basefim['PAIS'] =  DataFrame(dados['PAIS'] )

# %%
Basefim
# Out:
#        PCA_1   PAIS
# 0   0.396933    ARG
# 1  -1.949781    AUS
# 2  -1.274375    AUT
# 3  -1.303859    BEL
# 4   1.409218    BER
# 5  -1.016232    BRA
# 6  -1.750626    CAN
# 7   0.819461    CHI
# 8  -3.017538    CHN
# 9   0.001946    COL
# 10  7.980466    COK
# 11  2.187158    CRC
# 12 -2.428623    CZE
# 13 -0.083270    DEN
# 14  2.212996    DOM
# 15 -1.278626    FIN
# 16 -2.541993    FRA
# 17 -3.076132    GER
# 18 -2.465643    GBR
# 19 -1.209048    GRE
# 20  3.325055    GUA
# 21 -0.795653    HUN
# 22  1.758299    INA
# 23 -0.357583    IND
# 24 -1.045634    IRL
# 25  0.579553    ISR
# 26 -1.561983    ITA
# 27 -0.486180    JPN
# 28 -0.926353    KEN
# 29  0.838596  KOR,S
# 30  1.469013  KOR,N
# 31  1.737632    LUX
# 32  1.509250    MAS
# 33  1.766157    MRI
# 34 -1.005116    MEX
# 35  0.823643    MYA
# 36 -1.559266    NED
# 37 -0.762327    NZL
# 38 -0.558196    NOR
# 39  5.306817    PNG
# 40  1.780093    PHI
# 41 -2.295116    POL
# 42 -1.186285    POR
# 43 -2.142940    ROM
# 44 -3.071521    RUS
# 45  8.290538    SAM
# 46  3.122971    SIN
# 47 -1.907204    ESP
# 48 -0.847029    SWE
# 49 -1.124001    SUI
# 50  0.665282    TPE
# 51  1.235296    THA
# 52 -0.858110    TUR
# 53 -3.330127    USA

# %%
#transformando o componenete: Quanto mais rápido maior o indicador
Basefim['PCA_1'] = -Basefim['PCA_1']

# %%
#transformando o indicadoor de Performance:normalização de 0 a 1 e multiplicado por 100

Basefim['IndPerf'] = (Basefim['PCA_1'] - min(Basefim['PCA_1']))/( max(Basefim['PCA_1']) - min(Basefim['PCA_1']) ) *100

# %%
Basefim.describe().round(2)
# Out:
#        PCA_1  IndPerf
# count  54.00    54.00
# mean    0.00    71.34
# std     2.43    20.93
# min    -8.29     0.00
# 25%    -1.37    59.59
# 50%     0.78    78.05
# 75%     1.50    84.21
# max     3.33   100.00

# %%
Basefim.sort_values(by=['PCA_1'], ascending=False)
# Out:
#        PCA_1   PAIS     IndPerf
# 53  3.330127    USA  100.000000
# 17  3.076132    GER   97.814282
# 44  3.071521    RUS   97.774600
# 8   3.017538    CHN   97.310053
# 16  2.541993    FRA   93.217817
# 18  2.465643    GBR   92.560801
# 12  2.428623    CZE   92.242228
# 41  2.295116    POL   91.093356
# 43  2.142940    ROM   89.783830
# 1   1.949781    AUS   88.121621
# 47  1.907204    ESP   87.755234
# 6   1.750626    CAN   86.407822
# 26  1.561983    ITA   84.784484
# 36  1.559266    NED   84.761099
# 3   1.303859    BEL   82.563237
# 15  1.278626    FIN   82.346092
# 2   1.274375    AUT   82.309515
# 19  1.209048    GRE   81.747347
# 42  1.186285    POR   81.551470
# 49  1.124001    SUI   81.015492
# 24  1.045634    IRL   80.341116
# 5   1.016232    BRA   80.088102
# 34  1.005116    MEX   79.992445
# 28  0.926353    KEN   79.314656
# 52  0.858110    TUR   78.727406
# 48  0.847029    SWE   78.632047
# 21  0.795653    HUN   78.189934
# 37  0.762327    NZL   77.903156
# 38  0.558196    NOR   76.146535
# 27  0.486180    JPN   75.526814
# 23  0.357583    IND   74.420188
# 13  0.083270    DEN   72.059627
# 9  -0.001946    COL   71.326313
# 0  -0.396933    ARG   67.927309
# 25 -0.579553    ISR   66.355796
# 50 -0.665282    TPE   65.618068
# 7  -0.819461    CHI   64.291299
# 35 -0.823643    MYA   64.255310
# 29 -0.838596  KOR,S   64.126640
# 51 -1.235296    THA   60.712888
# 4  -1.409218    BER   59.216232
# 30 -1.469013  KOR,N   58.701674
# 32 -1.509250    MAS   58.355419
# 31 -1.737632    LUX   56.390109
# 22 -1.758299    INA   56.212266
# 33 -1.766157    MRI   56.144638
# 40 -1.780093    PHI   56.024718
# 11 -2.187158    CRC   52.521781
# 14 -2.212996    DOM   52.299430
# 46 -3.122971    SIN   44.468770
# 20 -3.325055    GUA   42.729763
# 39 -5.306817    PNG   25.675995
# 10 -7.980466    COK    2.668284
# 45 -8.290538    SAM    0.000000
